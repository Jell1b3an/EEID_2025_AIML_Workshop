# %% [markdown]
# <a href="https://colab.research.google.com/github/Jell1b3an/EEID_2025_AIML_Workshop/blob/course_practice/practice_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
setwd("./sample_data")

# %%
getwd()
# Out:
# [1] "/content/sample_data"

# %% [markdown]
# mark

# %% [markdown]
# **here**
